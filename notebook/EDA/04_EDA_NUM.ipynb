# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style("whitegrid")

# %%
UTILS = '/Users/krishnakalyan3/Educational/PumpIt/code/'
import sys
sys.path.append(UTILS)

# %%
# Custom imports
from utils import read_data
from utils import write_data
from param_config import config

# %%
train_x = read_data(config.d_xtrain)
train_y = read_data(config.a_ytest)

# %%
train_x.shape
# Out:
# (59400, 53)

# %%
data = train_x + train_y

# %%
test_x.shape
# Out:
# (14850, 53)

# %%
col_is_num = ['amount_tsh', 'gps_height', 'population', 'total_missing']

# %%
sns.distplot(train_x["amount_tsh"])

# %%
# Total static head (amount water available to waterpoint)
#plt.boxplot(train_x['amount_tsh'])
sns.boxplot(x=train_x["amount_tsh"], y=train_y['status_group'])

# %%
sns.distplot(train_x["gps_height"])

# %%
# Altitude of the well
#plt.boxplot(train_x['gps_height'])
sns.boxplot(x=train_x["gps_height"], y=train_y['status_group'])

# %%
sns.distplot(train_x["population"])

# %%
# Population around the well
#plt.boxplot(train_x['population'])
sns.boxplot(x=train_x["population"], y=train_y['status_group'])
# things are functional where there is more population

# %%
sns.distplot(train_x["total_missing"])

# %%
# missing values
#plt.boxplot(train_x['total_missing'])
sns.boxplot(x=train_x["total_missing"], y=train_y['status_group'])

# %%
col_is_num = ['amount_tsh', 'gps_height', 'population', 'total_missing'] 
df = train_x[col_is_num]
df_norm_col=(df-df.mean())/df.std()

sns.pairplot(df, kind="reg")
